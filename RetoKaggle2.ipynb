# %% [markdown]
# <a href="https://colab.research.google.com/github/lia07/v.retos/blob/main/RetoKaggle2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e610294f-9e0d-4d9a-adb9-c30f7a7ed032" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e610294f-9e0d-4d9a-adb9-c30f7a7ed032">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archive.csv to archive.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
nobel_prizes = pd.read_csv('archive.csv', index_col = 'Year')
nobel_prizes.head()
# Out:
#         Category  ... Death Country
# Year              ...
# 1901   Chemistry  ...       Germany
# 1901  Literature  ...        France
# 1901    Medicine  ...       Germany
# 1901       Peace  ...   Switzerland
# 1901       Peace  ...        France
#
# [5 rows x 17 columns]

# %%
val = nobel_prizes['Laureate Type'].unique()
val
# Out:
# array(['Individual', 'Organization'], dtype=object)

# %%
#La mayoria de los "Individuales" pertenecen a una universidad
indiv = nobel_prizes[(nobel_prizes['Laureate Type'] == 'Individual') & ~(nobel_prizes['Organization Name'].isna())]
indiv['Organization Name'].unique()
# Out:
# array(['Berlin University', 'Marburg University', 'Munich University',
#        'University College', 'Leiden University', 'Amsterdam University',
#        'Stockholm University', 'Finsen Medical Light Institute',
#        'École Polytechnique',
#        'École municipale de physique et de chimie industrielles (Municipal School of Industrial Physics and Chemistry)',
#        'Military Medical Academy', 'Royal Institution of Great Britain',
#        'Institute for Infectious Diseases', 'Kiel University',
#        'Sorbonne University', 'Pavia University', 'Madrid University',
#        'University of Cambridge',
#        'Landwirtschaftliche Hochschule (Agricultural College)',
#        'Institut Pasteur', 'University of Chicago', 'Victoria University',
#        'Goettingen University',
#        'Königliches Institut für experimentelle Therapie (Royal Institute for Experimental Therapy)',
#        'Leipzig University', 'Berne University',
#        'Marconi Wireless Telegraph Co. Ltd.', 'Strasbourg University',
#        'University of Heidelberg', 'Uppsala University',
#        'Würzburg University', 'Nancy University', 'Toulouse University',
#        'Rockefeller Institute for Medical Research',
#        'Swedish Gas-Accumulator Co.', 'University of Zurich',
#        'Harvard University', 'Vienna University',
#        'Frankfurt-on-the-Main University', 'Edinburgh University',
#        'Kaiser-Wilhelm-Institut (now Fritz-Haber-Institut) für physikalische Chemie und Electrochemie',
#        'Brussels University', 'Greifswald University',
#        'Copenhagen University',
#        'Bureau International des Poids et Mesures (International Bureau of Weights and Measures)',
#        'University of Oxford',
#        'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Physik',
#        'London University', 'Graz University', 'University of Toronto',
#        'California Institute of Technology (Caltech)', 'Halle University',
#        'Utrecht University',
#        'Sorbonne University, Institut Henri Poincaré',
#        'Technische Hochschule (Institute of Technology)',
#        'Calcutta University', 'I.G. Farbenindustrie A.G.',
#        'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biologie',
#        'Columbia University', 'General Electric Company',
#        'University of Rochester', 'Peter Brent Brigham Hospital',
#        'Institut du Radium', 'University of Freiburg im Breisgau',
#        'Liverpool University', 'National Institute for Medical Research',
#        'Innsbruck University', 'Birmingham University',
#        'Szeged University', 'Bell Telephone Laboratories',
#        'Kaiser-Wilhelm-Institut (now Max-Planck Institut) für Medizinische Forschung',
#        'Ghent University', 'Rome University',
#        'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#        'Eidgenössische Technische Hochschule (Swiss Federal Institute of Technology)',
#        'Munster University', 'University of California',
#        'Polytechnic Institute', 'Saint Louis University',
#        'Carnegie Institute of Technology',
#        'Kaiser-Wilhelm-Institut (now Max-Planck Institut) für Chemie',
#        'Washington University', 'University of Helsinki',
#        'Princeton University', 'Cornell University', 'Indiana University',
#        'Instituto de Biologia y Medicina Experimental (Institute for Biology and Experimental Medicine)',
#        'Department of Scientific and Industrial Research',
#        'Laboratorium der Farben-Fabriken J.R. Geigy A.G. (Laboratory of the J.R. Geigy Dye-Factory Co.)',
#        'University of Lisbon', 'Neurological Institute',
#        'Kyoto Imperial University', 'Cologne University', 'Mayo Clinic',
#        'Basel University', 'Bristol University',
#        'Laboratories of the Division of Medicine and Public Health, Rockefeller Foundation',
#        'Atomic Energy Research Establishment', 'Trinity College',
#        'Rowett Research Institute', 'Rutgers University',
#        'Stanford University', 'University of Freiburg',
#        'Staatliches Institut für makromolekulare Chemie (State Research Institute for Macromolecular Chemistry), Freiburg',
#        'Sheffield University', 'Harvard Medical School',
#        'Massachusetts General Hospital', 'Groningen University',
#        "Research Division of Infectious Diseases, Children's Medical Center",
#        'Western Reserve University',
#        'Max-Planck-Institut für medizinische Forschung',
#        'Karolinska Institutet, Nobel Medical Institute',
#        'Institute for Chemical Physics of the Academy of Sciences of the USSR',
#        'Columbia University Division, Cardio-Pulmonary Laboratory, Bellevue Hospital',
#        'Mainz University',
#        'Semiconductor Laboratory of Beckman Instruments, Inc.',
#        'University of Illinois',
#        'Istituto Superiore di Sanità (Chief Institute of Public Health)',
#        'Institute for Advanced Study', 'University of Wisconsin',
#        'P.N. Lebedev Physical Institute', 'University of Moscow',
#        'Polarographic Institute of the Czechoslovak Academy of Science',
#        'New York University, College of Medicine',
#        'Walter and Eliza Hall Institute for Medical Research',
#        'Technical University', 'MRC Laboratory of Molecular Biology',
#        'Academy of Sciences',
#        'Max-Planck-Institut für Kohlenforschung (Max-Planck-Institute for Carbon Research)',
#        'Institute of Technology', 'Australian National University',
#        'University of Oxford, Royal Society',
#        'Max-Planck-Institut für Zellchemie',
#        'Massachusetts Institute of Technology (MIT)',
#        'Tokyo University of Education', 'Rockefeller University',
#        'University of Chicago, Ben May Laboratory for Cancer Research',
#        'École Normale Supérieure',
#        'Max-Planck-Institut für Physikalische Chemie',
#        'Institute of Physical Chemistry', 'Karolinska Institutet',
#        'Yale University', 'National Institutes of Health',
#        'Imperial College', 'University of Oslo',
#        'The Netherlands School of Economics',
#        'Carnegie Institution of Washington',
#        'Institute for Biochemical Research',
#        'Royal Institute of Technology', 'University of Grenoble',
#        'National Research Council of Canada', 'Vanderbilt University',
#        'All Souls College', 'Brown University',
#        'University of Pennsylvania',
#        'Zoologisches Institut der Universität München',
#        'Konrad-Lorenz-Institut der Österreichischen Akademie der Wissen\xadschaften, Forschungsstelle für Ethologie',
#        'IBM Thomas J. Watson Research Center',
#        'Université Catholique de Louvain',
#        'Yale University, School of Medicine', 'University of Sussex',
#        'Imperial Cancer Research Fund Laboratory', 'Niels Bohr Institute',
#        'Nordita', 'The Institute for Cancer Research',
#        'Stanford Linear Accelerator Center',
#        'Université Libre de Bruxelles', 'University of Texas',
#        'Stockholm School of Economics', 'The Salk Institute',
#        'Veterans Administration Hospital', 'Glynn Research Laboratories',
#        'Carnegie Mellon University', 'Biozentrum der Universität',
#        'Johns Hopkins University School of Medicine', 'Bell Laboratories',
#        'Purdue University', 'Tufts University',
#        'Central Research Laboratories, EMI',
#        'Harvard University, Lyman Laboratory',
#        'International Centre for Theoretical Physics',
#        'Harvard University, Biological Laboratories',
#        'Université de Paris, Laboratoire Immuno-Hématologie',
#        'Jackson Laboratory', 'Kyoto University',
#        'The Wellcome Research Laboratories',
#        'Cold Spring Harbor Laboratory', 'Basel Institute for Immunology',
#        'CERN', 'The Medical Foundation of Buffalo',
#        'US Naval Research Laboratory',
#        'University of Texas Southwestern Medical Center at Dallas',
#        'Max-Planck-Institut für Festkörperforschung',
#        'Center for Study of Public Choice',
#        'Vanderbilt University School of Medicine',
#        'Institute of Cell Biology of the C.N.R.',
#        'Fritz-Haber-Institut der Max-Planck-Gesellschaft',
#        'IBM Zurich Research Laboratory', 'Université Louis Pasteur',
#        'Collège de France', 'Du Pont', 'Howard Hughes Medical Institute',
#        'Max-Planck-Institut für Biochemie',
#        'Max-Planck-Institut für Biophysik',
#        'École Nationale Supérieur des Mines de Paris',
#        "London University, King's College Hospital Medical School",
#        'Wellcome Research Laboratories',
#        'Fermi National Accelerator Laboratory', 'Digital Pathways, Inc.',
#        'University of Colorado',
#        'University of California School of Medicine',
#        'University of Washington', 'University of Bonn',
#        'City University of New York', "Brigham and Women's Hospital",
#        'Fred Hutchinson Cancer Research Center',
#        'Max-Planck-Institut für Biophysikalische Chemie',
#        'École Supérieure de Physique et Chimie',
#        'University of British Columbia', 'New England Biolabs',
#        'Massachusetts Institute of Technology (MIT), Center for Cancer Research',
#        'University of Southern California',
#        'Rheinische Friedrich-Wilhelms-Universität',
#        'National Institute of Environmental Health Sciences',
#        'McMaster University', 'Max-Planck-Institut für Chemie',
#        'Max-Planck-Institut für Entwicklungsbiologie', 'Rice University',
#        "St. Jude Children's Research Hospital",
#        'University of Zurich, Institute of Experimental Immunology',
#        'Aarhus University', 'Long Term Capital Management',
#        'National Institute of Standards and Technology',
#        'Northwestern University', 'SUNY Health Science Center',
#        'University of Texas Medical School at Houston',
#        'University of Tsukuba', 'Göteborg University',
#        'A.F. Ioffe Physico-Technical Institute', 'Texas Instruments',
#        'Nagoya University', 'The Scripps Research Institute',
#        'Imperial Cancer Research Fund', 'University of Colorado, JILA',
#        'Virginia Commonwealth University', 'Shimadzu Corp.',
#        'George Mason University', 'The Molecular Sciences Institute',
#        'The Wellcome Trust Sanger Institute', 'University of Tokyo',
#        'Associated Universities Inc.', 'New York University',
#        'University of Nottingham, School of Physics and Astronomy',
#        'Argonne National Laboratory',
#        'Technion - Israel Institute of Technology',
#        'Arizona State University', 'Federal Reserve Bank of Minneapolis',
#        'University of California, Kavli Institute for Theoretical Physics',
#        'Institut Français du Pétrole',
#        'University of Jerusalem, Center for RationalityHebrew',
#        'University of Maryland, Department of Economics and School of Public Policy',
#        'NHMRC Helicobacter pylori Research Laboratory, QEII Medical Centre',
#        'University of Western Australia',
#        'Max-Planck-Institut für Quantenoptik',
#        'Ludwig-Maximilians- Universität',
#        'Stanford University School of Medicine',
#        'University of Massachusetts Medical School',
#        'NASA Goddard Space Flight Center', 'University of Minnesota',
#        'University of Utah', 'Cardiff University',
#        'University of North Carolina', 'Universit&eacute; Paris-Sud',
#        'Unit&eacute; Mixte de Physique CNRS/THALES',
#        'Forschungszentrum J&uuml;lich',
#        'Marine Biological Laboratory (MBL)',
#        'Boston University Medical School',
#        'German Cancer Research Center',
#        'Regulation of Retroviral Infections Unit, Virology Department, Institut Pasteur',
#        'World Foundation for AIDS Research and Prevention',
#        'Enrico Fermi Institute, University of Chicago',
#        'High Energy Accelerator Research Organization (KEK)',
#        'Kyoto Sangyo University',
#        'Yukawa Institute for Theoretical Physics (YITP), Kyoto University',
#        'Weizmann Institute of Science',
#        'Standard Telecommunication Laboratories',
#        'Chinese University of Hong Kong', 'University of Delaware',
#        'Hokkaido University',
#        'London School of Economics and Political Science',
#        'University of Manchester', 'University of Strasbourg',
#        'Lawrence Berkeley National Laboratory',
#        'Johns Hopkins University', 'Space Telescope Science Institute',
#        'Duke University Medical Center', 'Harvard Business School',
#        'Gurdon Institute', 'Gladstone Institutes',
#        'Université de Strasbourg', 'University of Edinburgh',
#        'Janelia Research Campus, Howard Hughes Medical Institute',
#        'Max Planck Institute for Biophysical Chemistry',
#        'Toulouse School of Economics (TSE)',
#        'Norwegian University of Science and Technology (NTNU)',
#        'Meijo University', 'Francis Crick Institute',
#        'Clare Hall Laboratory', 'Duke University School of Medicine',
#        'Drew University', 'Kitasato University',
#        'China Academy of Traditional Chinese Medicine',
#        "Queen's University", 'University of Groningen',
#        'Tokyo Institute of Technology'], dtype=object)

# %%
#Todos los valores son NAN
org = nobel_prizes[nobel_prizes['Laureate Type'] == 'Organization']
org
# Out:
#      Category                       Prize  ... Death City Death Country
# Year                                       ...
# 1904    Peace  The Nobel Peace Prize 1904  ...        NaN           NaN
# 1910    Peace  The Nobel Peace Prize 1910  ...        NaN           NaN
# 1917    Peace  The Nobel Peace Prize 1917  ...        NaN           NaN
# 1938    Peace  The Nobel Peace Prize 1938  ...        NaN           NaN
# 1944    Peace  The Nobel Peace Prize 1944  ...        NaN           NaN
# 1947    Peace  The Nobel Peace Prize 1947  ...        NaN           NaN
# 1947    Peace  The Nobel Peace Prize 1947  ...        NaN           NaN
# 1954    Peace  The Nobel Peace Prize 1954  ...        NaN           NaN
# 1963    Peace  The Nobel Peace Prize 1963  ...        NaN           NaN
# 1963    Peace  The Nobel Peace Prize 1963  ...        NaN           NaN
# 1965    Peace  The Nobel Peace Prize 1965  ...        NaN           NaN
# 1969    Peace  The Nobel Peace Prize 1969  ...        NaN           NaN
# 1973    Peace  The Nobel Peace Prize 1973  ...      Hanoi       Vietnam
# 1977    Peace  The Nobel Peace Prize 1977  ...        NaN           NaN
# 1979    Peace  The Nobel Peace Prize 1979  ...   Calcutta         India
# 1981    Peace  The Nobel Peace Prize 1981  ...        NaN           NaN
# 1985    Peace  The Nobel Peace Prize 1985  ...        NaN           NaN
# 1988    Peace  The Nobel Peace Prize 1988  ...        NaN           NaN
# 1989    Peace  The Nobel Peace Prize 1989  ...        NaN           NaN
# 1991    Peace  The Nobel Peace Prize 1991  ...        NaN           NaN
# 1995    Peace  The Nobel Peace Prize 1995  ...        NaN           NaN
# 1997    Peace  The Nobel Peace Prize 1997  ...        NaN           NaN
# 1999    Peace  The Nobel Peace Prize 1999  ...        NaN           NaN
# 2001    Peace  The Nobel Peace Prize 2001  ...        NaN           NaN
# 2005    Peace  The Nobel Peace Prize 2005  ...        NaN           NaN
# 2006    Peace  The Nobel Peace Prize 2006  ...        NaN           NaN
# 2007    Peace  The Nobel Peace Prize 2007  ...        NaN           NaN
# 2012    Peace  The Nobel Peace Prize 2012  ...        NaN           NaN
# 2013    Peace  The Nobel Peace Prize 2013  ...        NaN           NaN
# 2015    Peace  The Nobel Peace Prize 2015  ...        NaN           NaN
#
# [30 rows x 17 columns]

# %%
categories = nobel_prizes['Category'].unique()
categories
# Out:
# array(['Chemistry', 'Literature', 'Medicine', 'Peace', 'Physics',
#        'Economics'], dtype=object)

# %%
#Se extrae una serie para cada categoria
chemistry = nobel_prizes[nobel_prizes['Category']=='Chemistry']
literature = nobel_prizes[nobel_prizes['Category']=='Literature']
medicine = nobel_prizes[nobel_prizes['Category']=='Medicine']
peace = nobel_prizes[nobel_prizes['Category']=='Peace']
physics = nobel_prizes[nobel_prizes['Category']=='Physics']
economics = nobel_prizes[nobel_prizes['Category']=='Economics']

# %%
#Testeando
chemistry_countries = chemistry['Birth Country'].value_counts().reset_index()
chemistry_countries
# Out:
#                                          index  Birth Country
# 0                     United States of America             57
# 1                                      Germany             23
# 2                               United Kingdom             22
# 3                                       France             10
# 4                                        Japan              7
# 5                                  Netherlands              5
# 6                                       Sweden              5
# 7                                       Russia              4
# 8                                       Canada              4
# 9                                      Austria              4
# 10                                 Switzerland              3
# 11       British Mandate of Palestine (Israel)              3
# 12                           Prussia (Germany)              3
# 13                                     Hungary              2
# 14                                    Scotland              2
# 15                                       Egypt              2
# 16                            Prussia (Poland)              2
# 17                            Germany (Poland)              2
# 18                                      Norway              2
# 19                                 New Zealand              2
# 20                                     Romania              2
# 21                   Austria-Hungary (Austria)              2
# 22                                     Belgium              1
# 23            Austria-Hungary (Czech Republic)              1
# 24                     Russian Empire (Poland)              1
# 25                    Russian Empire (Finland)              1
# 26                         Korea (South Korea)              1
# 27                   Austria-Hungary (Hungary)              1
# 28                                      Taiwan              1
# 29                                      Mexico              1
# 30  British Protectorate of Palestine (Israel)              1
# 31                                       Italy              1
# 32                   Austria-Hungary (Croatia)              1
# 33                            Germany (Russia)              1
# 34                                   Lithuania              1
# 35                      West Germany (Germany)              1
# 36                                     Denmark              1
# 37                     Russian Empire (Latvia)              1
# 38                            Poland (Ukraine)              1
# 39                                South Africa              1
# 40                                       China              1
# 41                                   Australia              1
# 42    Austria-Hungary (Bosnia and Herzegovina)              1
# 43                                       India              1
# 44                   Austrian Empire (Austria)              1
# 45                  Austria-Hungary (Slovenia)              1
# 46                           Bavaria (Germany)              1
# 47                                      Turkey              1

# %%
#Se encuentran los paises por categorias
literature_countries = literature['Birth Country'].value_counts().reset_index()
medicine_countries = medicine['Birth Country'].value_counts().reset_index()
peace_countries= peace['Birth Country'].value_counts().reset_index()
physics_countries = physics['Birth Country'].value_counts().reset_index()
economics_countries = economics['Birth Country'].value_counts().reset_index()

# %%
fig, ax = plt.subplots(2,3,figsize=(15, 10))
plt.subplots_adjust(hspace = 0.7)

#Gráficos
ax[0,0].bar(chemistry_countries['index'].iloc[0:5], chemistry_countries.iloc[0:5,1], label='Chemistry')
ax[0,1].bar(literature_countries['index'].iloc[0:5], literature_countries.iloc[0:5,1],label='Literature')
ax[0,2].bar(medicine_countries['index'].iloc[0:5], literature_countries.iloc[0:5,1],label='Medicine')
ax[1,0].bar(peace_countries['index'].iloc[0:5], peace_countries.iloc[0:5,1], label='Peace')
ax[1,1].bar(physics_countries['index'].iloc[0:5], physics_countries.iloc[0:5,1], label='Physics')
ax[1,2].bar(economics_countries['index'].iloc[0:5], economics_countries.iloc[0:5,1], label='Economics')

#Básicamente para rotar los ticks
ax[0,0].set_xticklabels(chemistry_countries['index'].iloc[0:5],rotation=90)
ax[0,1].set_xticklabels(literature_countries['index'].iloc[0:5],rotation=90)
ax[0,2].set_xticklabels(medicine_countries['index'].iloc[0:5],rotation=90)
ax[1,0].set_xticklabels(peace_countries['index'].iloc[0:5], rotation=90)
ax[1,1].set_xticklabels(physics_countries['index'].iloc[0:5], rotation=90)
ax[1,2].set_xticklabels(economics_countries['index'].iloc[0:5], rotation=90)

#Legends de cada gráfico
ax[0,0].legend()
ax[0,1].legend()
ax[0,2].legend()
ax[1,0].legend()
ax[1,1].legend()
ax[1,2].legend()
#Mostrar todos los gráficos
plt.show()
